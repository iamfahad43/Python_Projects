# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("First5.csv", on_bad_lines='skip')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6784 entries, ('0\t30W Solar Street Light with remote control', ' Automatic Day/Night switch\t1', '399\tClearance SALE!\t"30W Solar Street Light with remote control') to ('2 USB 2.0 Interfaces"\thttps://cdn.shopify.com/s/files/1/0343/7309/products/HL16ch1080kit_1024x1024.jpg?v=1574672986', nan, nan)
# Data columns (total 1 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   	TITLE	PRICE	CATEGORIES	DESCRIPTION	IMAGE_LINK  192 non-null    object
# dtypes: object(1)
# memory usage: 187.3+ KB

# %%
df1 = pd.read_excel("First5.xlsx", index_col=0)
df2 = pd.read_excel("Second5.xlsx", index_col=0)
df3 = pd.read_excel("Third.xlsx", index_col=0)
df4 = pd.read_excel("Fourth.xlsx", index_col=0)
df5 = pd.read_excel("Fifth.xlsx", index_col=0)
df6 = pd.read_excel("Six.xlsx", index_col=0)
len(df1), len(df2), len(df3), len(df4), len(df5), len(df6)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 146
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        147 non-null    object
#  1   PRICE        147 non-null    object
#  2   CATEGORIES   147 non-null    object
#  3   DESCRIPTION  147 non-null    object
#  4   IMAGE_LINK   147 non-null    object
# dtypes: object(5)
# memory usage: 6.9+ KB

# %%
df2 = pd.read_excel("Second5.xlsx", index_col=0)

# %%
df3 = pd.read_excel("Third.xlsx", index_col=0)

# %%
df4 = pd.read_excel("Fourth.xlsx", index_col=0)

# %%
df5 = pd.read_excel("Fifth.xlsx", index_col=0)

# %%
df6 = pd.read_excel("Six.xlsx", index_col=0)

# %%
len(df1), len(df2), len(df3), len(df4), len(df5), len(df6)
# Out:
# (147, 236, 103, 172, 64, 52)

# %%
test_df = pd.concat([df1 + df2 + df3 + df4 + df5 + df6])

# %%
len(test_df)
# Out:
# 236

# %%
test_df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [32], in <module>
# ----> 1 test_df.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
len(df1 + df2 + df3 + df4 + df5 + df6)
# Out:
# 236

# %%
len(df1), len(df2), len(df3), len(df4), len(df5), len(df6)
# Out:
# (147, 236, 103, 172, 64, 52)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 146
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        147 non-null    object
#  1   PRICE        147 non-null    object
#  2   CATEGORIES   147 non-null    object
#  3   DESCRIPTION  147 non-null    object
#  4   IMAGE_LINK   147 non-null    object
# dtypes: object(5)
# memory usage: 11.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 0 to 235
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        236 non-null    object
#  1   PRICE        236 non-null    object
#  2   CATEGORIES   236 non-null    object
#  3   DESCRIPTION  236 non-null    object
#  4   IMAGE_LINK   236 non-null    object
# dtypes: object(5)
# memory usage: 19.2+ KB

# %%
d1 = df1.append(df2)
# Out:
# /tmp/ipykernel_12608/264215846.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d1 = df1.append(df2)

# %%
len(d1)
# Out:
# 383

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383 entries, 0 to 235
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        383 non-null    object
#  1   PRICE        383 non-null    object
#  2   CATEGORIES   383 non-null    object
#  3   DESCRIPTION  383 non-null    object
#  4   IMAGE_LINK   383 non-null    object
# dtypes: object(5)
# memory usage: 18.0+ KB

# %%
d2 = d1.append(df3)
# Out:
# /tmp/ipykernel_12608/3566119872.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d2 = d1.append(df3)

# %%
len(d2)
# Out:
# 486

# %%
d3 = d2.append(df4)
# Out:
# /tmp/ipykernel_12608/1256471083.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d3 = d2.append(df4)

# %%
d4 = d3.append(df5)
# Out:
# /tmp/ipykernel_12608/1834965751.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d4 = d3.append(df5)

# %%
d5 = d4.append(df6)
# Out:
# /tmp/ipykernel_12608/1332620105.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   d5 = d4.append(df6)

# %%
len(d5)
# Out:
# 774

# %%
len(df1 + df2 + df3 + df4 + df5 + df6)
# Out:
# 236

# %%
len(df1), len(df2), len(df3), len(df4), len(df5), len(df6)
# Out:
# (147, 236, 103, 172, 64, 52)

# %%
147 + 236 + 103 + 172 + 64 + 52
# Out:
# 774

# %%
len(d5)
# Out:
# 774

# %%
data = d5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 774 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        774 non-null    object
#  1   PRICE        774 non-null    object
#  2   CATEGORIES   774 non-null    object
#  3   DESCRIPTION  770 non-null    object
#  4   IMAGE_LINK   774 non-null    object
# dtypes: object(5)
# memory usage: 36.3+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 146
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        147 non-null    object
#  1   PRICE        147 non-null    object
#  2   CATEGORIES   147 non-null    object
#  3   DESCRIPTION  147 non-null    object
#  4   IMAGE_LINK   147 non-null    object
# dtypes: object(5)
# memory usage: 11.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 0 to 235
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        236 non-null    object
#  1   PRICE        236 non-null    object
#  2   CATEGORIES   236 non-null    object
#  3   DESCRIPTION  236 non-null    object
#  4   IMAGE_LINK   236 non-null    object
# dtypes: object(5)
# memory usage: 19.2+ KB

# %%
len(data)
# Out:
# 774

# %%
data.head()
# Out:
#                                                TITLE  PRICE       CATEGORIES  \
# 0  30W Solar Street Light with remote control, Au...  1,399  Clearance SALE!
# 1  30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0  Clearance SALE!
# 2  *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0  Clearance SALE!
# 3  32 LED 16w Solar Street light with motion dete...  549.0  Clearance SALE!
# 4  *** Pack of 2*** Portable Solar LED Floodlight...  898.0  Clearance SALE!
#
#                                          DESCRIPTION  \
# 0  30W Solar Street Light with remote control, Au...
# 1  30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2  The price if for 3 complete units\n \n536 RECH...
# 3  32 LED 16w Solar Street light with motion dete...
# 4  Solar LED Flood Spot Light.\nHighly portable a...
#
#                                           IMAGE_LINK
# 0  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 1  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# ...

# %%
data.tail()
# Out:
#                                                 TITLE  PRICE  \
# 47  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...  9,600
# 48  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...  13,20
# 49  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...  16,00
# 50  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...  9,200
# 51  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...  12,00
#
#             CATEGORIES                                        DESCRIPTION  \
# 47  Wholesale DIY kits  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 48  Wholesale DIY kits  *Pack of 4 Kits*8 Channel HDMI DIY CCTV Kit Wi...
# 49  Wholesale DIY kits  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 50  Wholesale DIY kits  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 51  Wholesale DIY kits  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
#
#                                            IMAGE_LINK
# 47  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# ...

# %%
data["IMAGE_LINK"]
# Out:
# 0     https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 1     https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 2     https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 3     https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 4     https://cdn.shopify.com/s/files/1/0343/7309/pr...
#                             ...
# 47    https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 48    https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 49    https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 50    https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 51    https://cdn.shopify.com/s/files/1/0343/7309/pr...
# Name: IMAGE_LINK, Length: 774, dtype: object

# %%
# First DataFrame
ddf1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})
  
# Second DataFrame
ddf2 = pd.DataFrame({'id': ['B05', 'B06', 'B07', 'B08'],
                    'Name': ['XYZ', 'TUV', 'MNO', 'JKL']})
  
print(ddf1)
print(ddf2)
  
frames = [ddf1, ddf2]
  
result = pd.concat(frames)
display(result)
# Out:
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI
#     id Name
# 0  B05  XYZ
# 1  B06  TUV
# 2  B07  MNO
# 3  B08  JKL
#     id Name
# 0  A01  ABC
# 1  A02  PQR
# 2  A03  DEF
# 3  A04  GHI
# 0  B05  XYZ
# 1  B06  TUV
# 2  B07  MNO
# 3  B08  JKL

# %%
test_df = pd.concat([df1 , df2 , df3 , df4 , df5 , df6])

# %%
len(test_df)
# Out:
# 399

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 399 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           8 non-null      object
#  1   Name         8 non-null      object
#  2   TITLE        391 non-null    object
#  3   PRICE        391 non-null    object
#  4   CATEGORIES   391 non-null    object
#  5   DESCRIPTION  387 non-null    object
#  6   IMAGE_LINK   391 non-null    object
# dtypes: object(7)
# memory usage: 24.9+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      object
#  1   Name    4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
df1 = pd.read_excel("First5.xlsx", index_col=0)
df2 = pd.read_excel("Second5.xlsx", index_col=0)
df3 = pd.read_excel("Third.xlsx", index_col=0)
df4 = pd.read_excel("Fourth.xlsx", index_col=0)
df5 = pd.read_excel("Fifth.xlsx", index_col=0)
df6 = pd.read_excel("Six.xlsx", index_col=0)
len(df1), len(df2), len(df3), len(df4), len(df5), len(df6)
# Out:
# (147, 236, 103, 172, 64, 52)

# %%
test1_df = pd.concat([df1 , df2 , df3 , df4 , df5 , df6], axis=0, ignore_index=True)

# %%
test1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        774 non-null    object
#  1   PRICE        774 non-null    object
#  2   CATEGORIES   774 non-null    object
#  3   DESCRIPTION  770 non-null    object
#  4   IMAGE_LINK   774 non-null    object
# dtypes: object(5)
# memory usage: 30.4+ KB

# %%
test1_df.tail()
# Out:
#                                                  TITLE  PRICE  \
# 769  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...  9,600
# 770  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...  13,20
# 771  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...  16,00
# 772  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...  9,200
# 773  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...  12,00
#
#              CATEGORIES                                        DESCRIPTION  \
# 769  Wholesale DIY kits  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 770  Wholesale DIY kits  *Pack of 4 Kits*8 Channel HDMI DIY CCTV Kit Wi...
# 771  Wholesale DIY kits  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 772  Wholesale DIY kits  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 773  Wholesale DIY kits  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
#
#                                             IMAGE_LINK
# 769  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# ...

# %%
test1_df.head(222)
# Out:
#                                                  TITLE  PRICE  \
# 0    30W Solar Street Light with remote control, Au...  1,399
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0
# 3    32 LED 16w Solar Street light with motion dete...  549.0
# 4    *** Pack of 2*** Portable Solar LED Floodlight...  898.0
# ..                                                 ...    ...
# 217  HiLook by HikVision 16 Ch Turbo HD Kit - Embed...  14,99
# 218  HiLook by HikVision 32 Ch Turbo HD Kit - Embed...  16,99
# 219  HiLook by HikVision 32 Ch Turbo HD Kit - Embed...  18,49
# 220  HiLook by Hikvision 2MP IP camera kit - DIY, 3...  4,850
# 221  HiLook by Hikvision 4MP IP Kit - 4ch NVR with ...  7,195
#
#               CATEGORIES                                        DESCRIPTION  \
# 0        Clearance SALE!  30W Solar Street Light with remote control, Au...
# ...

# %%
Data = test1_df

# %%
Data.head()
# Out:
#                                                TITLE  PRICE       CATEGORIES  \
# 0  30W Solar Street Light with remote control, Au...  1,399  Clearance SALE!
# 1  30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0  Clearance SALE!
# 2  *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0  Clearance SALE!
# 3  32 LED 16w Solar Street light with motion dete...  549.0  Clearance SALE!
# 4  *** Pack of 2*** Portable Solar LED Floodlight...  898.0  Clearance SALE!
#
#                                          DESCRIPTION  \
# 0  30W Solar Street Light with remote control, Au...
# 1  30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2  The price if for 3 complete units\n \n536 RECH...
# 3  32 LED 16w Solar Street light with motion dete...
# 4  Solar LED Flood Spot Light.\nHighly portable a...
#
#                                           IMAGE_LINK
# 0  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 1  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        774 non-null    object
#  1   PRICE        774 non-null    object
#  2   CATEGORIES   774 non-null    object
#  3   DESCRIPTION  770 non-null    object
#  4   IMAGE_LINK   774 non-null    object
# dtypes: object(5)
# memory usage: 30.4+ KB

# %%
Data.isna().sum()
# Out:
# TITLE          0
# PRICE          0
# CATEGORIES     0
# DESCRIPTION    4
# IMAGE_LINK     0
# dtype: int64

# %%
Data["PRICE"].sum()
# Out:
# '1,399650.0990.0549.0898.02,750595.09,5001,095995.0950.0995.07,9959,9952,8953,4952,9953,1953,4953,8954,4954,5955,6954,1954,2504,4997,4956,8959,9954,8503,9501,7492,9952,7952,8993,6997,1957,2957,6506,2507,49524,9923,39420.0720.01,280349.03,995320.0480.0880.03,9955,2954,2954,9954,9955,7505,3956,6956,1957,4958,9956,79510,996,0956,5957,1957,4959,9959,2506,2958,3958,2502,7953,3994,9954,7955,1954,3997,99514,9911,4912,9914,4915,9921,9922,5019,4921,9936,6935,30420.0720.01,280349.05,995320.0480.0880.06,8957,9957,0957,6958,9958,7509,59512,4912,3915,9911,4910,4911,9912,4913,4910,9916,9915,9917,5022,9925,995,19916,9918,4930,9926,9936,5045,99420.0720.01,280349.0320.0480.0880.06,4501,6992,0494,3997,1505,8999,8995,3998,39914,508,7505,1955,5953,1954,9957,6954,9956,1958,9954,5955,6957,4958,99512,3915,994,2506,09510,494,4997,19512,494,5506,59511,997,49513,499,99516,996,2506,7509,2509,99510,9917,5022,9930,998,25015,991,0754,495999.01,5992,2992,4503,9991,295349.0399.0549.0459.0776.02,8953,9956,8952,9954,
# ...

# %%
max(Data["PRICE"])
# Out:
# '999.0'

# %%
min(Data["PRICE"])
# Out:
# '1,049'

# %%
len(Data["PRICE"])
# Out:
# 774

# %%
Data
# Out:
#                                                  TITLE  PRICE  \
# 0    30W Solar Street Light with remote control, Au...  1,399
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0
# 3    32 LED 16w Solar Street light with motion dete...  549.0
# 4    *** Pack of 2*** Portable Solar LED Floodlight...  898.0
# ..                                                 ...    ...
# 769  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...  9,600
# 770  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...  13,20
# 771  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...  16,00
# 772  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...  9,200
# 773  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...  12,00
#
#              CATEGORIES                                        DESCRIPTION  \
# 0       Clearance SALE!  30W Solar Street Light with remote control, Au...
# ...

# %%
template = pd.read_csv("Template.csv")

# %%
template
# Out:
#             Handle            Title  Body (HTML) Vendor  \
# 0  example-t-shirt  Example T-Shirt          NaN   Acme
# 1  example-t-shirt              NaN          NaN    NaN
# 2  example-t-shirt              NaN          NaN    NaN
# 3    example-pants    Example Pants          NaN   Acme
# 4      example-hat      Example Hat          NaN   Acme
#
#           Standardized Product Type Custom Product Type                  Tags  \
# 0  Apparel & Accessories > Clothing              Shirts  mens t-shirt example
# 1                               NaN                 NaN                   NaN
# 2                               NaN                 NaN                   NaN
# 3  Apparel & Accessories > Clothing               Pants    mens pants example
# 4  Apparel & Accessories > Clothing                 Hat      mens hat example
#
#   Published Option1 Name                         Option1 Value  ...  \
# 0      True        Title  Lithograph - Height: 9" x Width: 12"  ...
# ...

# %%
template.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Handle                                     5 non-null      object
#  1   Title                                      3 non-null      object
#  2   Body (HTML)                                0 non-null      float64
#  3   Vendor                                     3 non-null      object
#  4   Standardized Product Type                  3 non-null      object
#  5   Custom Product Type                        3 non-null      object
#  6   Tags                                       3 non-null      object
#  7   Published                                  3 non-null      object
#  8   Option1 Name                               3 non-null      object
#  9   Option1 Value                              5 non-null      object
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        774 non-null    object
#  1   PRICE        774 non-null    object
#  2   CATEGORIES   774 non-null    object
#  3   DESCRIPTION  770 non-null    object
#  4   IMAGE_LINK   774 non-null    object
# dtypes: object(5)
# memory usage: 30.4+ KB

# %%
template.isna().sum()
# Out:
# Handle                                       0
# Title                                        2
# Body (HTML)                                  5
# Vendor                                       2
# Standardized Product Type                    2
# Custom Product Type                          2
# Tags                                         2
# Published                                    2
# Option1 Name                                 2
# Option1 Value                                0
# Option2 Name                                 5
# Option2 Value                                5
# Option3 Name                                 5
# Option3 Value                                5
# Variant SKU                                  3
# Variant Grams                                0
# Variant Inventory Tracker                    4
# Variant Inventory Qty                        5
# Variant Inventory Policy                     0
# Variant Fulfillment Service                  0
# ...

# %%
template.columns
# Out:
# Index(['Handle', 'Title', 'Body (HTML)', 'Vendor', 'Standardized Product Type',
#        'Custom Product Type', 'Tags', 'Published', 'Option1 Name',
#        'Option1 Value', 'Option2 Name', 'Option2 Value', 'Option3 Name',
#        'Option3 Value', 'Variant SKU', 'Variant Grams',
#        'Variant Inventory Tracker', 'Variant Inventory Qty',
#        'Variant Inventory Policy', 'Variant Fulfillment Service',
#        'Variant Price', 'Variant Compare At Price',
#        'Variant Requires Shipping', 'Variant Taxable', 'Variant Barcode',
#        'Image Src', 'Image Position', 'Image Alt Text', 'Gift Card',
#        'SEO Title', 'SEO Description',
#        'Google Shopping / Google Product Category', 'Google Shopping / Gender',
#        'Google Shopping / Age Group', 'Google Shopping / MPN',
#        'Google Shopping / AdWords Grouping',
#        'Google Shopping / AdWords Labels', 'Google Shopping / Condition',
# ...

# %%
t1 = template.columns.copypy()

# %%
t1
# Out:
# Index(['Handle', 'Title', 'Body (HTML)', 'Vendor', 'Standardized Product Type',
#        'Custom Product Type', 'Tags', 'Published', 'Option1 Name',
#        'Option1 Value', 'Option2 Name', 'Option2 Value', 'Option3 Name',
#        'Option3 Value', 'Variant SKU', 'Variant Grams',
#        'Variant Inventory Tracker', 'Variant Inventory Qty',
#        'Variant Inventory Policy', 'Variant Fulfillment Service',
#        'Variant Price', 'Variant Compare At Price',
#        'Variant Requires Shipping', 'Variant Taxable', 'Variant Barcode',
#        'Image Src', 'Image Position', 'Image Alt Text', 'Gift Card',
#        'SEO Title', 'SEO Description',
#        'Google Shopping / Google Product Category', 'Google Shopping / Gender',
#        'Google Shopping / Age Group', 'Google Shopping / MPN',
#        'Google Shopping / AdWords Grouping',
#        'Google Shopping / AdWords Labels', 'Google Shopping / Condition',
# ...

# %%
type(t1)
# Out:
# pandas.core.indexes.base.Index

# %%
t2 = pd.DataFrame(columns=t1)

# %%
t2
# Out:
# Empty DataFrame
# ...

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Handle                                     0 non-null      object
#  1   Title                                      0 non-null      object
#  2   Body (HTML)                                0 non-null      object
#  3   Vendor                                     0 non-null      object
#  4   Standardized Product Type                  0 non-null      object
#  5   Custom Product Type                        0 non-null      object
#  6   Tags                                       0 non-null      object
#  7   Published                                  0 non-null      object
#  8   Option1 Name                               0 non-null      object
#  9   Option1 Value                              0 non-null      object
# ...

# %%
t2["Title"] = Data["TITLE"]

# %%
t2
# Out:
#     Handle                                              Title Body (HTML)  \
# 0      NaN  30W Solar Street Light with remote control, Au...         NaN
# 1      NaN  30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN
# 2      NaN  *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN
# 3      NaN  32 LED 16w Solar Street light with motion dete...         NaN
# 4      NaN  *** Pack of 2*** Portable Solar LED Floodlight...         NaN
# ..     ...                                                ...         ...
# 769    NaN  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...         NaN
# 770    NaN  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...         NaN
# 771    NaN  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...         NaN
# 772    NaN  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...         NaN
# 773    NaN  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...         NaN
#
#     Vendor Standardized Product Type Custom Product Type Tags Published  \
# ...

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Handle                                     0 non-null      object
#  1   Title                                      774 non-null    object
#  2   Body (HTML)                                0 non-null      object
#  3   Vendor                                     0 non-null      object
#  4   Standardized Product Type                  0 non-null      object
#  5   Custom Product Type                        0 non-null      object
#  6   Tags                                       0 non-null      object
#  7   Published                                  0 non-null      object
#  8   Option1 Name                               0 non-null      object
#  9   Option1 Value                              0 non-null      object
# ...

# %%
Data.head()
# Out:
#                                                TITLE  PRICE       CATEGORIES  \
# 0  30W Solar Street Light with remote control, Au...  1,399  Clearance SALE!
# 1  30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0  Clearance SALE!
# 2  *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0  Clearance SALE!
# 3  32 LED 16w Solar Street light with motion dete...  549.0  Clearance SALE!
# 4  *** Pack of 2*** Portable Solar LED Floodlight...  898.0  Clearance SALE!
#
#                                          DESCRIPTION  \
# 0  30W Solar Street Light with remote control, Au...
# 1  30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2  The price if for 3 complete units\n \n536 RECH...
# 3  32 LED 16w Solar Street light with motion dete...
# 4  Solar LED Flood Spot Light.\nHighly portable a...
#
#                                           IMAGE_LINK
# 0  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# 1  https://cdn.shopify.com/s/files/1/0343/7309/pr...
# ...

# %%
template.head()
# Out:
#             Handle            Title  Body (HTML) Vendor  \
# 0  example-t-shirt  Example T-Shirt          NaN   Acme
# 1  example-t-shirt              NaN          NaN    NaN
# 2  example-t-shirt              NaN          NaN    NaN
# 3    example-pants    Example Pants          NaN   Acme
# 4      example-hat      Example Hat          NaN   Acme
#
#           Standardized Product Type Custom Product Type                  Tags  \
# 0  Apparel & Accessories > Clothing              Shirts  mens t-shirt example
# 1                               NaN                 NaN                   NaN
# 2                               NaN                 NaN                   NaN
# 3  Apparel & Accessories > Clothing               Pants    mens pants example
# 4  Apparel & Accessories > Clothing                 Hat      mens hat example
#
#   Published Option1 Name                         Option1 Value  ...  \
# 0      True        Title  Lithograph - Height: 9" x Width: 12"  ...
# ...

# %%
t2.head()
# Out:
#   Handle                                              Title Body (HTML)  \
# 0    NaN  30W Solar Street Light with remote control, Au...         NaN
# 1    NaN  30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN
# 2    NaN  *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN
# 3    NaN  32 LED 16w Solar Street light with motion dete...         NaN
# 4    NaN  *** Pack of 2*** Portable Solar LED Floodlight...         NaN
#
#   Vendor Standardized Product Type Custom Product Type Tags Published  \
# 0    NaN                       NaN                 NaN  NaN       NaN
# 1    NaN                       NaN                 NaN  NaN       NaN
# 2    NaN                       NaN                 NaN  NaN       NaN
# 3    NaN                       NaN                 NaN  NaN       NaN
# 4    NaN                       NaN                 NaN  NaN       NaN
#
#   Option1 Name Option1 Value  ... Google Shopping / Custom Label 2  \
# ...

# %%
t2["Vendor"].fillna("ByTech")
# Out:
# 0      ByTech
# 1      ByTech
# 2      ByTech
# 3      ByTech
# 4      ByTech
#         ...
# 769    ByTech
# 770    ByTech
# 771    ByTech
# 772    ByTech
# 773    ByTech
# Name: Vendor, Length: 774, dtype: object

# %%
t2.head()
# Out:
#   Handle                                              Title Body (HTML)  \
# 0    NaN  30W Solar Street Light with remote control, Au...         NaN
# 1    NaN  30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN
# 2    NaN  *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN
# 3    NaN  32 LED 16w Solar Street light with motion dete...         NaN
# 4    NaN  *** Pack of 2*** Portable Solar LED Floodlight...         NaN
#
#   Vendor Standardized Product Type Custom Product Type Tags Published  \
# 0    NaN                       NaN                 NaN  NaN       NaN
# 1    NaN                       NaN                 NaN  NaN       NaN
# 2    NaN                       NaN                 NaN  NaN       NaN
# 3    NaN                       NaN                 NaN  NaN       NaN
# 4    NaN                       NaN                 NaN  NaN       NaN
#
#   Option1 Name Option1 Value  ... Google Shopping / Custom Label 2  \
# ...

# %%
t2["Vendor"] = t2["Vendor"].fillna("ByTech")

# %%
t2.head()
# Out:
#   Handle                                              Title Body (HTML)  \
# 0    NaN  30W Solar Street Light with remote control, Au...         NaN
# 1    NaN  30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN
# 2    NaN  *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN
# 3    NaN  32 LED 16w Solar Street light with motion dete...         NaN
# 4    NaN  *** Pack of 2*** Portable Solar LED Floodlight...         NaN
#
#    Vendor Standardized Product Type Custom Product Type Tags Published  \
# 0  ByTech                       NaN                 NaN  NaN       NaN
# 1  ByTech                       NaN                 NaN  NaN       NaN
# 2  ByTech                       NaN                 NaN  NaN       NaN
# 3  ByTech                       NaN                 NaN  NaN       NaN
# 4  ByTech                       NaN                 NaN  NaN       NaN
#
#   Option1 Name Option1 Value  ... Google Shopping / Custom Label 2  \
# ...

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Handle                                     0 non-null      object
#  1   Title                                      774 non-null    object
#  2   Body (HTML)                                0 non-null      object
#  3   Vendor                                     774 non-null    object
#  4   Standardized Product Type                  0 non-null      object
#  5   Custom Product Type                        0 non-null      object
#  6   Tags                                       0 non-null      object
#  7   Published                                  0 non-null      object
#  8   Option1 Name                               0 non-null      object
#  9   Option1 Value                              0 non-null      object
# ...

# %%
t2["Vendor"].isna().sum()
# Out:
# 0

# %%
t2["Vendor"]
# Out:
# 0      ByTech
# 1      ByTech
# 2      ByTech
# 3      ByTech
# 4      ByTech
#         ...
# 769    ByTech
# 770    ByTech
# 771    ByTech
# 772    ByTech
# 773    ByTech
# Name: Vendor, Length: 774, dtype: object

# %%
len(t2["Vendor"])
# Out:
# 774

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Handle                                     0 non-null      object
#  1   Title                                      774 non-null    object
#  2   Body (HTML)                                0 non-null      object
#  3   Vendor                                     774 non-null    object
#  4   Standardized Product Type                  0 non-null      object
#  5   Custom Product Type                        0 non-null      object
#  6   Tags                                       0 non-null      object
#  7   Published                                  0 non-null      object
#  8   Option1 Name                               0 non-null      object
#  9   Option1 Value                              0 non-null      object
# ...

# %%
template["Tags"]
# Out:
# 0    mens t-shirt example
# 1                     NaN
# 2                     NaN
# 3      mens pants example
# 4        mens hat example
# Name: Tags, dtype: object

# %%
Data["TITLE"]
# Out:
# 0      30W Solar Street Light with remote control, Au...
# 1      30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2      *** pack of 3 *** Rechargeable 536 Pistol Ligh...
# 3      32 LED 16w Solar Street light with motion dete...
# 4      *** Pack of 2*** Portable Solar LED Floodlight...
#                              ...
# 769    * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 770    *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...
# 771    *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 772    * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 773    * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
# Name: TITLE, Length: 774, dtype: object

# %%
converter = Data["TITLE"][1]

# %%
converter
# Out:
# '30w Solar Lighting kit, Solar Panel, 30w Solar floodlight, 3 x Indoor LED Bulbs, 5 in 1 USB charging cable'

# %%
converter = converter.replace(" ", "-")

# %%
converter
# Out:
# '30w-Solar-Lighting-kit,-Solar-Panel,-30w-Solar-floodlight,-3-x-Indoor-LED-Bulbs,-5-in-1-USB-charging-cable'

# %%
converter = converter.replace(",", "-")

# %%
converter
# Out:
# '30w-Solar-Lighting-kit--Solar-Panel--30w-Solar-floodlight--3-x-Indoor-LED-Bulbs--5-in-1-USB-charging-cable'

# %%
converter = Data["TITLE"][1]

# %%
converter
# Out:
# '30w Solar Lighting kit, Solar Panel, 30w Solar floodlight, 3 x Indoor LED Bulbs, 5 in 1 USB charging cable'

# %%
converter = converter.lower()

# %%
converter
# Out:
# '30w solar lighting kit, solar panel, 30w solar floodlight, 3 x indoor led bulbs, 5 in 1 usb charging cable'

# %%
converter = converter.replace(",", "")

# %%
converter
# Out:
# '30w solar lighting kit solar panel 30w solar floodlight 3 x indoor led bulbs 5 in 1 usb charging cable'

# %%
converter = converter.replace(" ", "-")

# %%
converter
# Out:
# '30w-solar-lighting-kit-solar-panel-30w-solar-floodlight-3-x-indoor-led-bulbs-5-in-1-usb-charging-cable'

# %%
template
# Out:
#             Handle            Title  Body (HTML) Vendor  \
# 0  example-t-shirt  Example T-Shirt          NaN   Acme
# 1  example-t-shirt              NaN          NaN    NaN
# 2  example-t-shirt              NaN          NaN    NaN
# 3    example-pants    Example Pants          NaN   Acme
# 4      example-hat      Example Hat          NaN   Acme
#
#           Standardized Product Type Custom Product Type                  Tags  \
# 0  Apparel & Accessories > Clothing              Shirts  mens t-shirt example
# 1                               NaN                 NaN                   NaN
# 2                               NaN                 NaN                   NaN
# 3  Apparel & Accessories > Clothing               Pants    mens pants example
# 4  Apparel & Accessories > Clothing                 Hat      mens hat example
#
#   Published Option1 Name                         Option1 Value  ...  \
# 0      True        Title  Lithograph - Height: 9" x Width: 12"  ...
# ...

# %%
Data
# Out:
#                                                  TITLE  PRICE  \
# 0    30W Solar Street Light with remote control, Au...  1,399
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0
# 3    32 LED 16w Solar Street light with motion dete...  549.0
# 4    *** Pack of 2*** Portable Solar LED Floodlight...  898.0
# ..                                                 ...    ...
# 769  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...  9,600
# 770  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...  13,20
# 771  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...  16,00
# 772  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...  9,200
# 773  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...  12,00
#
#              CATEGORIES                                        DESCRIPTION  \
# 0       Clearance SALE!  30W Solar Street Light with remote control, Au...
# ...

# %%
test = Data["TITLE"]

# %%
test
# Out:
# 0      30W Solar Street Light with remote control, Au...
# 1      30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2      *** pack of 3 *** Rechargeable 536 Pistol Ligh...
# 3      32 LED 16w Solar Street light with motion dete...
# 4      *** Pack of 2*** Portable Solar LED Floodlight...
#                              ...
# 769    * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 770    *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...
# 771    *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 772    * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 773    * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
# Name: TITLE, Length: 774, dtype: object

# %%
handle = test.replace(",", "")

# %%
handle
# Out:
# 0      30W Solar Street Light with remote control, Au...
# 1      30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2      *** pack of 3 *** Rechargeable 536 Pistol Ligh...
# 3      32 LED 16w Solar Street light with motion dete...
# 4      *** Pack of 2*** Portable Solar LED Floodlight...
#                              ...
# 769    * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 770    *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...
# 771    *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 772    * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 773    * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
# Name: TITLE, Length: 774, dtype: object

# %%
handle = handle.replace("*", "")

# %%
handle
# Out:
# 0      30W Solar Street Light with remote control, Au...
# 1      30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2      *** pack of 3 *** Rechargeable 536 Pistol Ligh...
# 3      32 LED 16w Solar Street light with motion dete...
# 4      *** Pack of 2*** Portable Solar LED Floodlight...
#                              ...
# 769    * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 770    *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...
# 771    *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 772    * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 773    * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
# Name: TITLE, Length: 774, dtype: object

# %%
converter = Data["TITLE"]

# %%
converter
# Out:
# 0      30W Solar Street Light with remote control, Au...
# 1      30w Solar Lighting kit, Solar Panel, 30w Solar...
# 2      *** pack of 3 *** Rechargeable 536 Pistol Ligh...
# 3      32 LED 16w Solar Street light with motion dete...
# 4      *** Pack of 2*** Portable Solar LED Floodlight...
#                              ...
# 769    * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...
# 770    *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...
# 771    *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...
# 772    * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...
# 773    * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...
# Name: TITLE, Length: 774, dtype: object

# %%
converter = converter.str.lower()

# %%
type(converter)
# Out:
# pandas.core.series.Series

# %%
converter
# Out:
# 0      30w solar street light with remote control, au...
# 1      30w solar lighting kit, solar panel, 30w solar...
# 2      *** pack of 3 *** rechargeable 536 pistol ligh...
# 3      32 led 16w solar street light with motion dete...
# 4      *** pack of 2*** portable solar led floodlight...
#                              ...
# 769    * pack of 4 kits *diy 8 channel ahd kit with 1...
# 770    *pack of 4 kits* 8 channel hdmi diy cctv kit w...
# 771    *pack of 4 kits* diy 16 channel cctv kit with ...
# 772    * pack of 4 kits* diy 8 channel cctv kit, with...
# 773    * pack of 4 kits* wireless 4 channel hd nvr ki...
# Name: TITLE, Length: 774, dtype: object

# %%
converter = converter.str.replace(",", "")

# %%
converter
# Out:
# 0      30w solar street light with remote control aut...
# 1      30w solar lighting kit solar panel 30w solar f...
# 2      *** pack of 3 *** rechargeable 536 pistol ligh...
# 3      32 led 16w solar street light with motion dete...
# 4      *** pack of 2*** portable solar led floodlight...
#                              ...
# 769    * pack of 4 kits *diy 8 channel ahd kit with 1...
# 770    *pack of 4 kits* 8 channel hdmi diy cctv kit w...
# 771    *pack of 4 kits* diy 16 channel cctv kit with ...
# 772    * pack of 4 kits* diy 8 channel cctv kit with ...
# 773    * pack of 4 kits* wireless 4 channel hd nvr ki...
# Name: TITLE, Length: 774, dtype: object

# %%
converter = converter.str.replace("*", "")
# Out:
# /tmp/ipykernel_12608/2476526016.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   converter = converter.str.replace("*", "")

# %%
converter
# Out:
# 0      30w solar street light with remote control aut...
# 1      30w solar lighting kit solar panel 30w solar f...
# 2       pack of 3  rechargeable 536 pistol lights (r3...
# 3      32 led 16w solar street light with motion dete...
# 4       pack of 2 portable solar led floodlight with ...
#                              ...
# 769     pack of 4 kits diy 8 channel ahd kit with 1.3...
# 770    pack of 4 kits 8 channel hdmi diy cctv kit wit...
# 771    pack of 4 kits diy 16 channel cctv kit with in...
# 772     pack of 4 kits diy 8 channel cctv kit with in...
# 773     pack of 4 kits wireless 4 channel hd nvr kit ...
# Name: TITLE, Length: 774, dtype: object

# %%
converter = converter.str.replace(" ", "-")

# %%
converter
# Out:
# 0      30w-solar-street-light-with-remote-control-aut...
# 1      30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2      -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3      32-led-16w-solar-street-light-with-motion-dete...
# 4      -pack-of-2-portable-solar-led-floodlight-with-...
#                              ...
# 769    -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770    pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771    pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772    -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773    -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
# Name: TITLE, Length: 774, dtype: object

# %%
t2
# Out:
#     Handle                                              Title Body (HTML)  \
# 0      NaN  30W Solar Street Light with remote control, Au...         NaN
# 1      NaN  30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN
# 2      NaN  *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN
# 3      NaN  32 LED 16w Solar Street light with motion dete...         NaN
# 4      NaN  *** Pack of 2*** Portable Solar LED Floodlight...         NaN
# ..     ...                                                ...         ...
# 769    NaN  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...         NaN
# 770    NaN  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...         NaN
# 771    NaN  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...         NaN
# 772    NaN  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...         NaN
# 773    NaN  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...         NaN
#
#      Vendor Standardized Product Type Custom Product Type Tags Published  \
# ...

# %%
t2["Handle"] = converter

# %%
t2["Handle"].isna().sum()
# Out:
# 0

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
template
# Out:
#             Handle            Title  Body (HTML) Vendor  \
# 0  example-t-shirt  Example T-Shirt          NaN   Acme
# 1  example-t-shirt              NaN          NaN    NaN
# 2  example-t-shirt              NaN          NaN    NaN
# 3    example-pants    Example Pants          NaN   Acme
# 4      example-hat      Example Hat          NaN   Acme
#
#           Standardized Product Type Custom Product Type                  Tags  \
# 0  Apparel & Accessories > Clothing              Shirts  mens t-shirt example
# 1                               NaN                 NaN                   NaN
# 2                               NaN                 NaN                   NaN
# 3  Apparel & Accessories > Clothing               Pants    mens pants example
# 4  Apparel & Accessories > Clothing                 Hat      mens hat example
#
#   Published Option1 Name                         Option1 Value  ...  \
# 0      True        Title  Lithograph - Height: 9" x Width: 12"  ...
# ...

# %%
Data["CATEGORIES"]
# Out:
# 0         Clearance SALE!
# 1         Clearance SALE!
# 2         Clearance SALE!
# 3         Clearance SALE!
# 4         Clearance SALE!
#               ...
# 769    Wholesale DIY kits
# 770    Wholesale DIY kits
# 771    Wholesale DIY kits
# 772    Wholesale DIY kits
# 773    Wholesale DIY kits
# Name: CATEGORIES, Length: 774, dtype: object

# %%
Standardized_type = f"Home > " + Data["CATEGORIES"]

# %%
Standardized_type
# Out:
# 0         Home > Clearance SALE!
# 1         Home > Clearance SALE!
# 2         Home > Clearance SALE!
# 3         Home > Clearance SALE!
# 4         Home > Clearance SALE!
#                  ...
# 769    Home > Wholesale DIY kits
# 770    Home > Wholesale DIY kits
# 771    Home > Wholesale DIY kits
# 772    Home > Wholesale DIY kits
# 773    Home > Wholesale DIY kits
# Name: CATEGORIES, Length: 774, dtype: object

# %%
t2["Standardized Product Type"] = Standardized_type

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
template
# Out:
#             Handle            Title  Body (HTML) Vendor  \
# 0  example-t-shirt  Example T-Shirt          NaN   Acme
# 1  example-t-shirt              NaN          NaN    NaN
# 2  example-t-shirt              NaN          NaN    NaN
# 3    example-pants    Example Pants          NaN   Acme
# 4      example-hat      Example Hat          NaN   Acme
#
#           Standardized Product Type Custom Product Type                  Tags  \
# 0  Apparel & Accessories > Clothing              Shirts  mens t-shirt example
# 1                               NaN                 NaN                   NaN
# 2                               NaN                 NaN                   NaN
# 3  Apparel & Accessories > Clothing               Pants    mens pants example
# 4  Apparel & Accessories > Clothing                 Hat      mens hat example
#
#   Published Option1 Name                         Option1 Value  ...  \
# 0      True        Title  Lithograph - Height: 9" x Width: 12"  ...
# ...

# %%
template["Tags"]
# Out:
# 0    mens t-shirt example
# 1                     NaN
# 2                     NaN
# 3      mens pants example
# 4        mens hat example
# Name: Tags, dtype: object

# %%
t2["Handle"].dtype
# Out:
# dtype('O')

# %%
type(t2["Handle"])
# Out:
# pandas.core.series.Series

# %%
t2["Handle"]
# Out:
# 0      30w-solar-street-light-with-remote-control-aut...
# 1      30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2      -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3      32-led-16w-solar-street-light-with-motion-dete...
# 4      -pack-of-2-portable-solar-led-floodlight-with-...
#                              ...
# 769    -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770    pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771    pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772    -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773    -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
# Name: Handle, Length: 774, dtype: object

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
t2["Published"] = "TRUE"

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
t2["Option1 Name"] = "Title"

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
t2["Tags"] = "Hikvision Hilook CCTV Camera DIY Kit LED LCD Screen"

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
t2["Image Src"] = Data["IMAGE_LINK"]

# %%
t2["Image Position"] = 1

# %%
t2["Gift Card"] = "FALSE"

# %%
t2["Google Shopping / Google Product Category"] = t2["Standardized Product Type"]

# %%
t2
# Out:
#                                                 Handle  \
# 0    30w-solar-street-light-with-remote-control-aut...
# 1    30w-solar-lighting-kit-solar-panel-30w-solar-f...
# 2    -pack-of-3--rechargeable-536-pistol-lights-(r3...
# 3    32-led-16w-solar-street-light-with-motion-dete...
# 4    -pack-of-2-portable-solar-led-floodlight-with-...
# ..                                                 ...
# 769  -pack-of-4-kits-diy-8-channel-ahd-kit-with-1.3...
# 770  pack-of-4-kits-8-channel-hdmi-diy-cctv-kit-wit...
# 771  pack-of-4-kits-diy-16-channel-cctv-kit-with-in...
# 772  -pack-of-4-kits-diy-8-channel-cctv-kit-with-in...
# 773  -pack-of-4-kits-wireless-4-channel-hd-nvr-kit-...
#
#                                                  Title Body (HTML)  Vendor  \
# 0    30W Solar Street Light with remote control, Au...         NaN  ByTech
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...         NaN  ByTech
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...         NaN  ByTech
# ...

# %%
t2["Google Shopping / Gender"] = "Unisex"

# %%
t2["Google Shopping / Age Group"] = "Adult"

# %%
t2["Google Shopping / Condition"] = "new"

# %%
t2["Google Shopping / Custom Product"] = "FALSE"

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 774 entries, 0 to 773
# Data columns (total 51 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Handle                                     774 non-null    object
#  1   Title                                      774 non-null    object
#  2   Body (HTML)                                0 non-null      object
#  3   Vendor                                     774 non-null    object
#  4   Standardized Product Type                  774 non-null    object
#  5   Custom Product Type                        0 non-null      object
#  6   Tags                                       774 non-null    object
#  7   Published                                  774 non-null    object
#  8   Option1 Name                               774 non-null    object
#  9   Option1 Value                              0 non-null      object
# ...

# %%
t2["Price / International"] = Data["PRICE"]

# %%
Data
# Out:
#                                                  TITLE  PRICE  \
# 0    30W Solar Street Light with remote control, Au...  1,399
# 1    30w Solar Lighting kit, Solar Panel, 30w Solar...  650.0
# 2    *** pack of 3 *** Rechargeable 536 Pistol Ligh...  990.0
# 3    32 LED 16w Solar Street light with motion dete...  549.0
# 4    *** Pack of 2*** Portable Solar LED Floodlight...  898.0
# ..                                                 ...    ...
# 769  * Pack of 4 Kits *DIY 8 Channel AHD kit with 1...  9,600
# 770  *Pack of 4 Kits* 8 Channel HDMI DIY CCTV Kit W...  13,20
# 771  *Pack of 4 Kits* DIY 16 Channel CCTV Kit with ...  16,00
# 772  * Pack of 4 Kits* DIY 8 Channel CCTV Kit, with...  9,200
# 773  * Pack of 4 kits* Wireless 4 Channel HD NVR Ki...  12,00
#
#              CATEGORIES                                        DESCRIPTION  \
# 0       Clearance SALE!  30W Solar Street Light with remote control, Au...
# ...

# %%
Final_Dataset = t2

# %%
len(Final_Dataset)
# Out:
# 774

# %%
Final_Dataset.isna().sum().plot.line()
# Out:
# ---------------------------------------------------------------------------
# DuplicateLabelError                       Traceback (most recent call last)
# Input In [254], in <module>
# ----> 1 Final_Dataset.isna().sum().plot.line()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:5847, in DataFrame.isna(self)
#    5844 @doc(NDFrame.isna, klass=_shared_doc_kwargs["klass"])
#    5845 def isna(self) -> DataFrame:
#    5846     result = self._constructor(self._mgr.isna(func=isna))
# -> 5847     return result.__finalize__(self, method="isna")
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:5549, in NDFrame.__finalize__(self, other, method, **kwargs)
#    5546 for name in other.attrs:
#    5547     self.attrs[name] = other.attrs[name]
# -> 5549 self.flags.allows_duplicate_labels = other.flags.allows_duplicate_labels
#    5550 # For subclasses using _metadata.
#    5551 for name in set(self._metadata) & set(other._metadata):
#
# ...

# %%
description1 = pd.read_csv("Description1.csv")
description2 = pd.read_csv("Description2.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [255], in <module>
# ----> 1 description1 = pd.read_csv("Description1.csv")
#       2 description2 = pd.read_csv("Description2.csv")
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
description = description1.append(description2)
# Out:
# /tmp/ipykernel_12608/3153744428.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   description = description1.append(description2)

# %%
len(description)
# Out:
# 774

# %%
description
# Out:
#      \tDESCRIPTION
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ..             ...
# 286            286
# 287            287
# 288            288
# 289            289
# 290            290
#
# [774 rows x 1 columns]

# %%
description.head()
# Out:
#    \tDESCRIPTION
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4

# %%
description_1 = pd.read_excel("Description1.xlsx")

# %%
description_2 = pd.read_excel("Description2.xlsx")

# %%
description_1
# Out:
#      Unnamed: 0                                        DESCRIPTION
# 0             0  [<div class="description" itemprop="descriptio...
# 1             1  [<div class="description" itemprop="descriptio...
# 2             2  [<div class="description" itemprop="descriptio...
# 3             3  [<div class="description" itemprop="descriptio...
# 4             4  [<div class="description" itemprop="descriptio...
# ..          ...                                                ...
# 481         481  [<div class="description" itemprop="descriptio...
# 482         482  [<div class="description" itemprop="descriptio...
# 483         483  [<div class="description" itemprop="descriptio...
# 484         484  [<div class="description" itemprop="descriptio...
# 485         485  [<div class="description" itemprop="descriptio...
#
# [486 rows x 2 columns]

# %%
Description = description_1.append(description_2)
# Out:
# /tmp/ipykernel_12608/3695264972.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Description = description_1.append(description_2)

# %%
Description
# Out:
#      Unnamed: 0                                        DESCRIPTION
# 0             0  [<div class="description" itemprop="descriptio...
# 1             1  [<div class="description" itemprop="descriptio...
# 2             2  [<div class="description" itemprop="descriptio...
# 3             3  [<div class="description" itemprop="descriptio...
# 4             4  [<div class="description" itemprop="descriptio...
# ..          ...                                                ...
# 283         283  [<div class="description" itemprop="descriptio...
# 284         284  [<div class="description" itemprop="descriptio...
# 285         285  [<div class="description" itemprop="descriptio...
# 286         286  [<div class="description" itemprop="descriptio...
# 287         287  [<div class="description" itemprop="descriptio...
#
# [774 rows x 2 columns]

# %%
Final_Dataset["Body (HTML)"] = Description
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [265], in <module>
# ----> 1 Final_Dataset["Body (HTML)"] = Description
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3645, in DataFrame.__setitem__(self, key, value)
#    3643     self._setitem_array(key, value)
#    3644 elif isinstance(value, DataFrame):
# -> 3645     self._set_item_frame_value(key, value)
#    3646 elif (
#    3647     is_list_like(value)
#    3648     and not self.columns.is_unique
#    3649     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3650 ):
#    3651     # Column to set is duplicated
#    3652     self._setitem_array([key], value)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:3775, in DataFrame._set_item_frame_value(self, key, value)
#    3773 len_cols = 1 if is_scalar(cols) else len(cols)
# ...

# %%
des = Description["DESCRIPTION"]

# %%
des
# Out:
# 0      [<div class="description" itemprop="descriptio...
# 1      [<div class="description" itemprop="descriptio...
# 2      [<div class="description" itemprop="descriptio...
# 3      [<div class="description" itemprop="descriptio...
# 4      [<div class="description" itemprop="descriptio...
#                              ...
# 283    [<div class="description" itemprop="descriptio...
# 284    [<div class="description" itemprop="descriptio...
# 285    [<div class="description" itemprop="descriptio...
# 286    [<div class="description" itemprop="descriptio...
# 287    [<div class="description" itemprop="descriptio...
# Name: DESCRIPTION, Length: 774, dtype: object

# %%
type(des)
# Out:
# pandas.core.series.Series

# %%
len(des)
# Out:
# 774

# %%
des.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 774 entries, 0 to 287
# Series name: DESCRIPTION
# Non-Null Count  Dtype
# --------------  -----
# 774 non-null    object
# dtypes: object(1)
# memory usage: 12.1+ KB

# %%
print(des[des.duplicated()])
# Out:
# 91     [<div class="description" itemprop="descriptio...
# 92     [<div class="description" itemprop="descriptio...
# 93     [<div class="description" itemprop="descriptio...
# 94     [<div class="description" itemprop="descriptio...
# 96     [<div class="description" itemprop="descriptio...
#                              ...
# 275    [<div class="description" itemprop="descriptio...
# 276    [<div class="description" itemprop="descriptio...
# 277    [<div class="description" itemprop="descriptio...
# 278    [<div class="description" itemprop="descriptio...
# 282    [<div class="description" itemprop="descriptio...
# Name: DESCRIPTION, Length: 251, dtype: object

# %%
des.duplicated().value_counts()
# Out:
# False    523
# True     251
# Name: DESCRIPTION, dtype: int64

# %%
tes_des = des.drop_duplicates(inplace=True)

# %%
len(tes_des)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [277], in <module>
# ----> 1 len(tes_des)
#
# TypeError: object of type 'NoneType' has no len()
